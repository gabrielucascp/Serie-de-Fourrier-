# %% [markdown]
# # Série Trigonométrica de Fourier
#
# Gabriel Lucas Costa Pereira
# Análise de Sinais e Sistemas Lineares
#
# Departamento de Engenharia Elétrica
# Universidade Federal do Rio Grande do Norte
# Natal-RN
# Abril - 2016

# %% [markdown]
# # Resumo
#
# Este trabalho apresenta a representação de dois sinais periódicos em sua respectiva forma trigonométrica da Série de Fourrier. São utilizados métodos de programação para gerar gráficos, tornando possível observar experimentalmente a eficácia do método matemático

# %% [markdown]
# ## Sumário
# 1. Introdução
# 2. Cálculos da Série Trigonométrica de Fourier utilizados
# 3. Exemplo 1
#    1. Representação a partir da Série Trigonométrica de Fourier
#    2. Espectro de Amplitude
# 4. Exemplo 2
#    1. Representação a partir da Série Trigonométrica de Fourier
#    2. Espectro de Amplitude

# %% [markdown]
# # 1 Introdução
#
# O presente relatório desenvolve os cálculos de dois exemplos de sinais periódicos representando-os a partir da Série de Fourier na forma trigonométrica. E através de linguagens de programação python e $\LaTeX$ apresenta os gráficos das duas funções no domínio do tempo e os gráficos de suas respectivas amplitudes e fases no domínio da frequência.
# A Série de Fourier foi desenvolvida pelo matemático e Jean-Baptiste-Joseph Fourier (1768 - 1830) no início do século $\textit{IXX}$. A série foi elaborada quando Fourier ocupava-se nos estudos sobre propagação de calor em corpos sólidos. O matemático afirmou em um artigo sobre a teoria do calor, que uma função contínua ou descontínua em um certo período poderia ser representada através de uma soma de senoides.
#
# $$x(t) = a_0 + \sum\limits_{n=1}^{\infty} a_n\cos n\omega_0T_0 + b_n\sin n\omega_0T_0 \,\,\,\,\,\,\,\,Equação\,(I.1)$$
#
# A banca de avaliação de sua tese era compostas por grandes nomes da ciência como Laplace e Lagrange. O primeiro, não estava de acordo com a teoria de Fourier alegando que esta não era geral como seu autor o afirmou. Essa relutância do revisor em aceitar a teoria também escondia certa carga de posição pessoal, já que Laplace e seus pupilos estavam abordando a mesma teoria de calor em uma abordagem diferente. Mesmo com quatro dos revisores estarem a favor da publicação do artigo, a reprovação por Lagrange teve peso o suficiente para a recusa da publicação.
# Quinze anos após esse episódio, Fourier publicou uma obra dedicada inteiramente à sua teoria de calor contendo sua série. E algum tempo depois certas peculiaridades da série foram provadas, fazendo com que até hoje seja de extrema utilidade na área da ciência teórica e aplicada.

# %% [markdown]
# # 2 Cálculos da Série Trigonométrica de Fourier utilizados
#
# A Série de Fourier em sua forma trigonométrica é definida pela Equação I.1. A partir da função x(t) é possível encontrar os coeficientes $a_0\,, a_n\,$ e $b_n$. Também é possível definir a frequência fundamenteal $\omega_0$ e o período $T_0$ a partir da observação do gráfico da função x(t).
# ![Função Periódica Exemplo](http://www.dt.fee.unicamp.br/~www/ea612/img2233.gif)
# $$Gráfico 1: Exemplo\,de\,função\,periódica$$
# O período é dado por $T_0$ = $\frac{1}{f_0}$ e $\omega_0$ = $2\pi f_0$. Dessa forma tem-se que,
# $$\omega_0 = \frac{2\pi}{T_0} \,\,\, Equação\,1.1$$
# Para determinar $a_0$, integra-se os dois lados da Equação I.1 no intervalo $T_0$
# $$\int\limits_{T_0} x(t)dt = a_0 \int\limits_{T_0} dt + \sum\limits_{n=1}^{\infty} \int\limits_{T_0} a_n\cos n\omega_0T_0 dt + \int\limits_{T_0} b_n\sin n\omega_0T_0 dt$$
# A área sob as funções senoidais em qualquer $T_0$ é nula, pois completam n ciclos completos neste intervalo. Assim temos
# $$\int\limits_{T_0} x(t)dt = a_0 \int\limits_{T_0} dt = a_0T_0$$
# $$a_0 = \frac{1}{T_0}\int\limits_{T_0} x(t)dt\,\,\, Equação\,1.2$$
# Para determinar os coeficientes $a_n$ e $b_n$, toma-se certa integral $I$ como ferramenta matemática, definida por
# $$I\,=\,\int\limits_{T_0} \cos n\omega_0t\,\cos m\omega_0t\,dt$$
# Apartir da identidade trigonométrica
# $\cos x \cos y\, = \frac{1}{2}\, \left[\cos (x\,-\,y)\, + \,\cos (x\,+\,y)\right]$,
# $$I\,= \frac{1}{2}\,\left(\,\int\limits_{T_0} \cos (n\,+\,m)\omega_0t\,dt \,+\, \int\limits_{T_0}\cos (n\,-\,m)\omega_0t\,dt\right)$$
# Pelo mesmo motivo em que a Equação 1.2, a área sob n + m e n - m é nula, mas quando n = m a segunda integral não é nula. Tem-se assim, que quando n = m
# $$I\,= \frac{1}{2}\,\int\limits_{T_0}\,dt = \frac{T_0}{2}$$
# Então
# $$\int\limits_{T_0} \cos n\omega_0t\,\cos m\omega_0t\,dt$$
# $$\int\limits_{T_0} \cos n\omega_0t\,\cos m\omega_0t\,dt =
#   \begin{cases}
#     0             & \quad n\, \neq \,m \\
#     \frac{T_0}{2} & \quad  n\, = \,m\, \neq \,0\\
#   \end{cases}
# \,\,\,\, Equação\,1.3.1$$
# $$\\ \int\limits_{T_0} \sin n\omega_0t\,\sin m\omega_0t\,dt =
#   \begin{cases}
#     0             & \quad n\, \neq \,m \\
#     \frac{T_0}{2} & \quad  n\, = \,m\, \neq \,0\\
#   \end{cases}
#   \,\,\,\, Equação\,1.3.2
# $$
# $$\int\limits_{T_0} \sin n\omega_0t\,\cos m\omega_0t\,dt \,=\,0\,\,\,\, Equação\,1.3.3$$
# Essas expressões servirão de ferramenta quando a Equação I.1 for multiplicada por $\cos m\omega_0t$ e esta for integrada
#
# $$\int\limits_{T_0} x(t)\,\cos m\omega_0t\,dt = a_0 \int\limits_{T_0}\,\cos m\omega_0t\,dt + \sum\limits_{n=1}^{\infty} \int\limits_{T_0}\,a_n\cos n\omega_0T_0\,\cos m\omega_0t dt + \int\limits_{T_0} b_n\sin n\omega_0T_0\,\cos m\omega_0t\, dt$$
# Com a Equação 1.3.3 a última integral do lado direito é igual a zero, e a primeira integral do mesmo lado é nula por completar n ciclos em qualquer período $T_0$. Dessa forma, resta a integral da esquerda e a segunda da direita. Esta última será nula quando $n\, \neq \,m$, mas quando $n\, = \,m$, de acordo com a Equação 1.3.1, o resultado da integral será $\frac{T_0}{2}$. Então, com esse raciocínio, e o aplicando para o caso de multiplicar os dois lados da Equação I.1 por $\sin m\omega_0t$, pode-se chegar ao valor dos coeficientes $a_n\, e b_n$.
#
# $$a_n = \frac{2}{T_0}\int\limits_{T_0} x(t)\, \cos n\omega_0t\, dt\,\,\, Equação\,1.4.1$$
# $$b_n = \frac{2}{T_0}\int\limits_{T_0} x(t)\, \sin n\omega_0t\, dt\,\,\, Equação\,1.4.2$$
# Para encontrar a fómula das amplitudes $C_n$ tem-se
# $$C_n = \frac{1}{T_0}\int\limits_{T_0} x(t)\,\mathrm{e}^{-jn\omega_0 t}\,dt\,\,\, Equação\,1.5.1$$
# $$Re\left[C_n\right] = \frac{a_n}{2}\,\,\, Equação\,1.5.2$$
# $$-Im\left[C_n\right] = \frac{b_n}{2}\,\,\, Equação\,1.5.3$$

# %% [markdown]
# # 4 Exemplo 2
#
# O segundo exemplo proposto para ilustrar a Série de Fourier está representado pelo gráfico abaixo:
# ![Exemplo 2](https://raw.githubusercontent.com/gabrielucascp/Serie-de-Fourrier-/42fee0316ddf6be510926b0aef8ce6a2a3ade53e/Exemplo2.png)
# Oservando que a função completa um ciclo em um intervalo de $2\pi$, tem-se $T_0$ = $2\pi$ e $\omega_0\, = \,\frac{2\pi}{T_0}\, = \,1$. E esse é o comportamento da função observado em seu período:
# $$ x(t) =
#   \begin{cases}
#     \frac{t}{2\pi} & \quad  0\, <\, t\, <\,2\pi\\
#   \end{cases}
#   \,\,\,\, Equação\,2.1
# $$
#
# ## A. Representação a partir da Série Trigonométrica de Fourier
# Aplicando a Equação 1.5.1 à x(t) = $\frac{t}{2\pi}$ e desenvolvendo-a, tem-se
# $$C_n = \frac{1}{2\pi}\int\limits_{0}^{2\pi}\frac{t}{2\pi}\,\mathrm{e}^{-jn\omega_0 t}\,dt$$
# $$C_n = \frac{(2\pi n \sin (n2\pi) + \cos(n2\pi) -1)}{4\pi^2 n^2} \,+\, \left(\frac{(-2\pi n \cos (n2\pi) + \sin(n2\pi))}{j4\pi^2 n^2}\right) \,\,\,\,Equação\, 2.2$$
# $$|C_n| = \sqrt{ \left[\frac{(2\pi n \sin (n2\pi) + \cos(n2\pi) -1)}{4\pi^2 n^2}\right]^2 \,+\, \left[\frac{(-2\pi n \cos (n2\pi) + \sin(n2\pi))}{4\pi^2 n^2}\right]^2} \,\,\,\,Equação\, 2.3$$
# Apartir da Equação 2.2 pode-se obter os coeficientes $a_n$ e $b_n$ com as equações 1.5.2 e 1.5.3. Outra alternativa também está disponível, que é a utilização das equações 1.4.1 e 1.4.2.
# $$a_n = \frac{2}{2\pi}\int\limits_{T_0} \, \frac{t}{2\pi}\, \cos n\omega_0t\, dt$$
# $$b_n = \frac{2}{2\pi}\int\limits_{T_0} \frac{t}{2\pi}\, \sin n\omega_0t\, dt$$
# Desenvolvendo as equações, tem-se as seguintes expressões representando $a_n$ e $b_n$ respectivamente:
# $$a_n = \frac{(2\pi n \sin (n2\pi) + \cos(n2\pi) -1)}{4\pi^2 n^2} \,\,\,\,Equação\, 2.4$$
# $$b_n = \frac{(-2\pi n \cos (n2\pi) + \sin(n2\pi))}{4\pi^2 n^2} \,\,\,\,Equação\, 2.5$$
# E com as equações 2.4 e 2.5 é possível, com a linguagem Python, representar o gráfico Exemplo 2 na Série Trigonométrica de Fourier.
# O código abaixo irá gerar três gráficos. O primeiro irá representar a série com 4 harmônicas, o segundo com 10 harmonicas e o terceiro com 110. Com essas representações é possível observar que a série com a soma de n tendendo ao infinito estará mais perto de estar idêntica ao Exemplo 2.

# %%
#-----------------------Função x(t) = t/2*pi p/ 0 < t < 2*pi na Série Trigonométrica de Fourier---------------------#

#Definindo biblioteca matplotlib inline para gerar o gráfico na própria página
# %matplotlib inline 
figure(figsize=(17, 10))
import matplotlib
from pylab import *
from numpy import pi, arange
import math
#Definindo as expressos dos coeficientes an e bn, respectivamente e
pe=pi*pi

def a(n):
    y =(1./(2.*pe*n*n))*(2.*pi*n*sin(2.*pi*n)+cos(2.*pi*n)-1.)
    return y
def b(n):
    y =(1/(2.*pe*n*n))*(-2.*pi*n*cos(2.*pi*n)+sin(2.*pi*n))
    return y



#Série com n = 4
subplot (231)
def X(t):
    y=0.5
    for n in range(1,4, 1):
        y=y+a(n)*cos(n*t) + b(n)*sin(n*t) 
    return y

t1 = arange(-4*pi,4*pi,0.01)
x1 = X(t1)

plot(t1,x1)
grid()
ylabel ('x(t)')


#Série com n = 10
subplot (232)
def X(t):
    y=0.5
    for n in range(1,10, 1):
        y=y+a(n)*cos(n*t) + b(n)*sin(n*t)
    return y

t2 = arange(-4*pi,4*pi,0.01)
x2 = X(t2)
plot(t2,x2)
grid()
xlabel ('t')

#Série com n = 110
subplot (233)
def X(t):
    y=0.5
    for n in range(1,110, 1):
        y=y+a(n)*cos(n*t) + b(n)*sin(n*t)
    return y

t3 = arange(-4*pi,4*pi,0.01)
x3 = X(t3)
plot(t3,x3)

grid()

# %% [markdown]
# ## B. Espectro de Amplitude
#
# Abaixo está a representação das amplitudes de x(t) no domínio da frequência, chamada de Espectro de Amplitude.

# %%
#-----------------------Função x(t) = t/2*pi p/ 0 < t < 2*pi na Série Trigonométrica de Fourier---------------------#
                       #-------Espectro de Amplitude e espectro de fase--------#
#Definindo biblioteca matplotlib inline para gerar o gráfico na própria página
# %matplotlib inline 
figure(figsize=(7, 5))
import matplotlib
from pylab import *
from numpy import pi, arange
import math
# Definindo expressão das amplitudes
def C(n):
    
    y = sqrt(((2.*pi*n*sin(n*2.*pi) + cos(n*2.*pi)-1.)/(4.*pi*pi*n*n))**2 + ((-2.*pi*n*cos(n*2.*pi)-sin(n*2.*pi))/(4.*pi*pi*n*n))**2)
    return y
plot([0,1,2,3,4], [C(0.), C(1.),C(2.),C(3.),C(4.)], 'bo')
axis([0, 5, 0, C(4.) + 0.2])
grid()    
ylabel ('Amplitude |Cn|')
xlabel ('n')
# Out:
# C:\Users\Sebastiao\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in double_scalars
